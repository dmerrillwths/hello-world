# %% [markdown]
# This is my first attempt at creating a Jupyter notebook
# for one-dimensional kinematics.

# %% [markdown]
# Import libraries needed to run this code...

# %%
#import pandas as pd
import numpy as np
#import math as math
#import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Find out what we know ... time or distance
# (assuming we already know initial velocity and acceleration)

# %%
print('This is a one dimensional kinematics solver.')
print('This assumes we know acceleration, initial velocity, and' )
print('      the distance OR time.')
known = input('What is known, distance (d) or time (t)? ')
known = str(known)
# Out:
# This is a one dimensional kinematics solver.
# This assumes we know acceleration, initial velocity, and
#       the distance OR time.
# What is known, distance (d) or time (t)? t

# %%
if known == 't':
    t = float(input('What is the time (seconds)? ')) 
    a = str(input('Is this freefall problem? yes or no: ' ))
    if a == 'yes':
         print('This is a freefall problem. Acceleration = 9.8 m/s^2')
         accel = 9.8  #m/s^2
    if a == 'no':
         accel = float(input ('What is the acceleration? '))
    v0 = float(input('What is the objects initial velocity (m/s)? '))
# maybe ask students to fill in this part themselves ...
# What is the equation for distance? What is the equation for final velocity?, Print out the results:
    d = round(v0* t + 0.5 * accel* t**2, 2)
    print ('Distance traveled is:', d, ' m')
    vf = round((v0**2 + (2.0 * accel*d))**0.5, 2)
    print ('Final velocity = ', vf, 'm/s')
# Out:
# What is the time (seconds)? 6
# Is this freefall problem? yes or no: yes
# This is a freefall problem. Acceleration = 9.8 m/s^2
# What is the objects initial velocity (m/s)? 1
# Distance traveled is: 182.4  m
# Final velocity =  59.8 m/s

# %%
if known =='d':
    d = float(input('What is the distance? '))
    a = str(input('Is this freefall problem? yes or no: ' ))
    if a == 'yes':
         print('This is a freefall problem. Acceleration = 9.8 m/s^2')
         accel = 9.8  #m/s^2
    if a == 'no':
         accel = float(input ('What is the acceleration? '))
    v0 = float(input('What is the objects initial velocity (m/s)? '))
    polya = accel/2   
    polyb = v0
    polyc = -d 
    p = [polya, polyb, polyc]
    #print (np.roots(p))
    timeroot = np.roots(p)
    if timeroot[1] <0:
        t = round(timeroot[0], 2)
    if timeroot[0] <0:
        t = round(timeroot[1], 2)
    print('time = ', t, ' sec')
    vf = round((v0**2 + (2.0 * accel*d))**0.5, 2)
    print ('Final velocity = ', vf, 'm/s')
# Out:
# What is the distance? 150
# Is this freefall problem? yes or no: yes
# This is a freefall problem. Acceleration = 9.8 m/s^2
# What is the objects initial velocity (m/s)? 2
# time =  5.33  sec
# Final velocity =  54.26 m/s

# %% [markdown]
# Graph distance as a function of time:

# %%
#if known =='d':
#    t = ans

print('Do you want a graph of distance and velocity vs time? ')
graph = input('Type yes or no: ')
graph = str(graph)

#graph = str(input('Would you like to graph this motion vs time? y or n: '))
# graph results as a function of time:    
if graph == 'yes':
    distdata = True
    n = 0
    distg = []
    velg = []
    timeg = []
    while distdata == True:
        t1 = float(n/2)
        velg.append(v0 + accel*t1)
        distg.append ((v0*t1+(accel/2)*t1**2))
        timeg.append (t1)
        n = n+1
        if n >= (2*t+1):
            distdata = False

    maxd = round((distg[(n-1)])+4.999, -1)  # roundUP to nearest 10
    maxv = round((velg[(n-1)])+4.999, -1)
    #print (timeg)
    #print (velg)
  # graph distance vs time  
    plt.figure(figsize = (15,10))
    plt.title('Distance vs Time', fontsize=30)
    plt.tick_params(labelsize=20)
    plt.axes().get_xaxis().set_visible(True)
    plt.axes().get_yaxis().set_visible(True)
    plt.axis([0,(n/2),0,maxd])
    plt.grid()
    plt.ylabel('Distance, m', fontsize = 20)
    plt.xlabel(' Time, sec ', fontsize = 20)
    plt.plot(timeg, distg)
    plt.show()
# Out:
# Do you want a graph of distance and velocity vs time?
# Type yes or no: yes

# %% [markdown]
# Here's code to graph velocity versus time:

# %%
    plt.figure(figsize = (15,10))
    plt.title('Velocity vs Time', fontsize=30)
    plt.tick_params(labelsize=20)
    plt.axes().get_xaxis().set_visible(True)
    plt.axes().get_yaxis().set_visible(True)
    plt.axis([0,(n/2),0,maxv])
    plt.grid()
    plt.ylabel('Velocity, m/s', fontsize = 20)
    plt.xlabel(' Time, sec ', fontsize = 20)
    
    plt.plot(timeg, velg)
    plt.show()
